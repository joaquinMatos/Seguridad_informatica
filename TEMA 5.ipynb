# %%
# acesso a datos

frutas = ["manzana", "banana", "cereza"]
numeros = [1, 2, 3, 4, 5]
mixto = ["texto", 123, True, 3.14]

print (frutas[1])

for numero in numeros:
    print(numero)
# Out:
# banana
# 1
# 2
# 3
# 4
# 5

# %%
mixto[1] = "hola mundo"
print(mixto)
# Out:
# ['texto', 'hola mundo', True, 3.14]

# %%
frutas.append("naranja")    # Agrega un elemento al final
frutas.remove("manzana")    # Elimina un elemento específico
frutas.pop()                # Elimina el último elemento
# Out:
# 'naranja'

# %%
#tuplas
colores = ("rojo", "verde", "azul")
print(colores[1])    # Imprime "verde"
# Out:
# verde

# %%
animales = {"gato", "perro", "pez"}

# %%
animales.add("pájaro")     # Agrega un elemento
animales.remove("pez")     # Elimina un elemento

for animal in animales:
    print(animal)
# Out:
# perro
# gato
# pájaro

# %%
#diccionario

persona = {
    "nombre": "Joaquin Emanuel",
    "materno": "Zetina",
    "paterno": "Matos",
    "edad": 20,
    "ciudad": "Quintana Roo",
    "altura": 1.72,
    "peso": 54
}

# %%
print(persona["altura"])
# Out:
# 1.72

# %%
def imc(peso,altura,nombre):
    
    imc_p = peso / pow(altura)
    
    if imc_p < 18.5:
        print(f"estas bajo de peso {nombre}")
    elif imc_p > 18.5 and imc_p < 24.9:
        print(f"estas normalito {nombre}")
    else:
    
    
peso_p = persona["peso"]
altura_p = persona["altura"]    
nombre_p = persona["nombre"] 
    
imc(peso_p,altura_p,nombre_p)
# Out:
#   Cell In[75], line 12
#     peso_p = persona["peso"]
#                             ^
# IndentationError: expected an indented block after 'else' statement on line 9

# %%
#ejercio de clase ,  peso (kg) / [estatura (m)]2

def saludo_personalizado (persona["nombre"]):
    formula = persona["edad"] / persona["altura"]
    print(formula)
# Out:
#   Cell In[66], line 3
#     def saludo_personalizado (persona["nombre"]) :
#                                      ^
# SyntaxError: invalid syntax

# %%
saludo_personalizado("Juan")  # Esto imprimirá "¡Hola, Juan!" en la pantalla.
# Out:
# ¡Hola, Juan!

# %%
print(persona["nombre"])    # Imprime "Juan"
persona["edad"] = 26        # Modifica el valor de "edad"
# Out:
# Juan

# %%
for k in persona:
    print(k)
# Out:
# nombre
# edad
# ciudad

# %%
for v in persona.values():
    print(v)
# Out:
# Juan
# 26
# Madrid

# %%
for k,v in persona.items():
    print(f"la clave es {k} y el valor:{v}")
# Out:
# la clave es nombre y el valor:Juan
# la clave es edad y el valor:26
# la clave es ciudad y el valor:Madrid
